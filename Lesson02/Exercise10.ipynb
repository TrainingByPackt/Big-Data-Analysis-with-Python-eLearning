# %% [markdown]
# ## Exercise 10: Creating a Graph for a Mathematical Function

# %%
import numpy as np
x = np.linspace(0,100,200)
y = np.sin(x)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Optional: Importing seaborn to match figure given in book

# %%
import seaborn as sns
sns.set()

# %%
fig, ax = plt.subplots()
ax.plot(x, y)

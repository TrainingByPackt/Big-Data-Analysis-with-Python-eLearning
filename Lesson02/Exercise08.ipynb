# %% [markdown]
# ## Exercise 8: Plotting an Analytical Function

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# Optional: Importing seaborn so that figures match those in the book exactly, code works even otherwise too

# %%
import seaborn as sns
sns.set()

# %%
x = np.linspace(-50, 50, 100)
y = np.power(x, 2)

# %%
plt.plot(x, y)

# %%
y_hat = np.power(x, 3)
plt.plot(x, y_hat)
